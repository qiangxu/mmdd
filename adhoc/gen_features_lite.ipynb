# %%
import pandas as pd
from tqdm.notebook import tqdm
import glob

# %%
lobs_df = pd.read_csv("adhoc/orderbook_logs/btcusdt_orderbook_20241218_165805.csv")
lobs_pkl = "adhoc/orderbook_logs/btcusdt_orderbook_20241218_165805.pickle"

# %% [markdown]
# ### PREPROCESS LOB FILE

# %%
lobs_df = lobs_df.set_index(lobs_df.columns[0])
lobs_df.index.names = ['']

# %%
lobs_df.set_index('receive_ts', inplace=True)
lobs_df = lobs_df[~lobs_df.index.duplicated(keep='first')]
lobs_df.sort_values(by=['receive_ts'], inplace=True)
lobs_df.reset_index(inplace=True)

# %%
lobs_df[['bid_price_0', 'ask_price_0']].head()
# Out:
#    bid_price_0  ask_price_0
# 0     103780.0     103780.0
# 1     103780.0     103780.0
# 2     103780.0     103780.0
# 3     103777.7     103777.7
# 4     103777.7     103777.7

# %%
lobs_df['mid_price'] = (lobs_df['ask_price_0'] + lobs_df['bid_price_0']) / 2

# %%
lobs_df['returns'] = (lobs_df['mid_price'] / lobs_df['mid_price'].shift(1) - 1).fillna(0)

# %%
windows = {60: '1m', 300: '5m', 900: '15m'}
for w in windows.keys():
    lobs_df[f'gain_{windows[w]}'] = lobs_df.set_index('receive_ts')['returns'].rolling(w).apply(
        lambda x: x[x > 0].sum()
    ).reset_index()['returns']

    print(lobs_df.head(2))

    lobs_df[f'loss_{windows[w]}'] = lobs_df.set_index('receive_ts')['returns'].rolling(w).apply(
        lambda x: x[x < 0].sum()
    ).reset_index()['returns']
# Out:
#             receive_ts  bid_price_0  bid_vol_0  bid_price_1  bid_vol_1  \
# 0  2024-12-18 08:58:06     103780.0    2.27683     103778.6     0.0001
# 1  2024-12-18 08:58:07     103780.0    1.96353     103775.1     0.0000
#
#    bid_price_2  bid_vol_2  bid_price_3  bid_vol_3  bid_price_4  ...  \
# 0     103778.5    0.03860     103775.1    0.00100     103774.1  ...
# 1     103761.1    0.33546     103758.0    0.78287     103755.6  ...
#
#    ask_price_7  ask_vol_7  ask_price_8  ask_vol_8  ask_price_9  ask_vol_9  \
# 0     103783.1    0.00000     103785.7    0.00000     103786.5        0.0
# 1     103782.9    0.04831     103786.0    0.19275     103788.6        0.0
#
#                   exchange_ts  mid_price  returns  gain_1m
# 0  2024-12-18T08:58:06.095042   103780.0      0.0      NaN
# 1  2024-12-18T08:58:07.093771   103780.0      0.0      NaN
#
# [2 rows x 45 columns]
#             receive_ts  bid_price_0  bid_vol_0  bid_price_1  bid_vol_1  \
# 0  2024-12-18 08:58:06     103780.0    2.27683     103778.6     0.0001
# 1  2024-12-18 08:58:07     103780.0    1.96353     103775.1     0.0000
#
#    bid_price_2  bid_vol_2  bid_price_3  bid_vol_3  bid_price_4  ...  \
# 0     103778.5    0.03860     103775.1    0.00100     103774.1  ...
# 1     103761.1    0.33546     103758.0    0.78287     103755.6  ...
#
#    ask_price_8  ask_vol_8  ask_price_9  ask_vol_9                 exchange_ts  \
# 0     103785.7    0.00000     103786.5        0.0  2024-12-18T08:58:06.095042
# 1     103786.0    0.19275     103788.6        0.0  2024-12-18T08:58:07.093771
#
#    mid_price  returns  gain_1m  loss_1m  gain_5m
# 0   103780.0      0.0      NaN      NaN      NaN
# 1   103780.0      0.0      NaN      NaN      NaN
#
# [2 rows x 47 columns]
#             receive_ts  bid_price_0  bid_vol_0  bid_price_1  bid_vol_1  \
# 0  2024-12-18 08:58:06     103780.0    2.27683     103778.6     0.0001
# 1  2024-12-18 08:58:07     103780.0    1.96353     103775.1     0.0000
#
#    bid_price_2  bid_vol_2  bid_price_3  bid_vol_3  bid_price_4  ...  \
# 0     103778.5    0.03860     103775.1    0.00100     103774.1  ...
# 1     103761.1    0.33546     103758.0    0.78287     103755.6  ...
#
#    ask_price_9  ask_vol_9                 exchange_ts  mid_price  returns  \
# 0     103786.5        0.0  2024-12-18T08:58:06.095042   103780.0      0.0
# 1     103788.6        0.0  2024-12-18T08:58:07.093771   103780.0      0.0
#
#    gain_1m  loss_1m  gain_5m  loss_5m  gain_15m
# 0      NaN      NaN      NaN      NaN       NaN
# 1      NaN      NaN      NaN      NaN       NaN
#
# [2 rows x 49 columns]

# %%
lobs_df.describe()
# Out:
#          bid_price_0     bid_vol_0    bid_price_1     bid_vol_1  \
# count   26641.000000  26641.000000   26641.000000  26641.000000
# mean   104512.150377      3.002141  104510.676773      0.105340
# std       392.935047      2.478657     392.952995      0.548406
# min    103412.500000      0.000010  103412.400000      0.000000
# 25%    104194.100000      1.050830  104192.200000      0.000100
# 50%    104525.600000      2.536510  104523.700000      0.000200
# 75%    104823.600000      4.405130  104821.500000      0.042680
# max    105350.000000     23.194450  105349.900000     30.568780
#
#          bid_price_2     bid_vol_2    bid_price_3     bid_vol_3  \
# count   26641.000000  26641.000000   26641.000000  26641.000000
# mean   104508.915975      0.093529  104506.378297      0.088939
# std       398.081530      0.421495     402.723182      0.387226
# min     94219.000000      0.000000   94218.000000      0.000000
# 25%    104191.400000      0.000070  104188.900000      0.000000
# 50%    104521.000000      0.000200  104519.400000      0.000200
# 75%    104820.500000      0.041110  104819.000000      0.038500
# max    105349.800000     23.342010  105349.600000     15.357740
#
#          bid_price_4     bid_vol_4  ...    ask_price_9     ask_vol_9  \
# count   26641.000000  26641.000000  ...   26641.000000  26641.000000
# mean   104498.631256      0.093973  ...  104977.426613      0.181687
# std       612.494891      0.836345  ...    3565.021910      6.226202
# min     33000.000000      0.000000  ...  103414.500000      0.000000
# 25%    104184.700000      0.000000  ...  104225.400000      0.000000
# 50%    104517.000000      0.000200  ...  104566.000000      0.000150
# 75%    104815.800000      0.038400  ...  104884.500000      0.033620
# max    105349.500000    115.796280  ...  158543.300000    541.099419
#
#            mid_price       returns       gain_1m       loss_1m       gain_5m  \
# count   26641.000000  2.664100e+04  26582.000000  26582.000000  26342.000000
# mean   104512.161985 -7.445986e-08      0.000830     -0.000836      0.004126
# std       392.932286  6.830916e-05      0.000839      0.000867      0.003630
# min    103412.550000 -8.948374e-04      0.000000     -0.005635      0.000132
# 25%    104194.100000  0.000000e+00      0.000227     -0.001155      0.001641
# 50%    104525.600000  0.000000e+00      0.000526     -0.000524      0.002595
# 75%    104823.600000  0.000000e+00      0.001159     -0.000238      0.005514
# max    105350.000000  1.222881e-03      0.005225      0.000000      0.016514
#
#             loss_5m      gain_15m      loss_15m
# count  26342.000000  25742.000000  25742.000000
# mean      -0.004152      0.012346     -0.012375
# std        0.003834      0.010339      0.010858
# min       -0.020396      0.001917     -0.043965
# 25%       -0.005957      0.005034     -0.021892
# 50%       -0.002595      0.008091     -0.007755
# 75%       -0.001460      0.017414     -0.004327
# max        0.000000      0.044644     -0.002015
#
# [8 rows x 48 columns]

# %% [markdown]
# ### GEN FEATURE FILE

# %%
features_df = pd.DataFrame({'receive_ts': lobs_df['receive_ts']})

# %%
for column in lobs_df.filter(regex="_price_").columns.values:
    features_df[f'dist_{column}'] = (lobs_df[column] / lobs_df['mid_price'] - 1) * 1e06

# %%
for side in ['bid', 'ask']:
    features_df[f'{side}_cumul_0'] = lobs_df[f'{side}_price_0'] * lobs_df[f'{side}_vol_0']

for i in range(1, 10):
    for side in ['bid', 'ask']:
        features_df[f'{side}_cumul_{i}'] = (
                features_df[f'{side}_cumul_{i - 1}'] + lobs_df[f'{side}_price_{i}'] * lobs_df[f'{side}_vol_{i}']
        )

# %%
for i in range(10):
    features_df[f'national_imbalance_{i}'] = (
            (features_df[f'ask_cumul_{i}'] - features_df[f'bid_cumul_{i}']) /
            (features_df[f'ask_cumul_{i}'] + features_df[f'bid_cumul_{i}'])
    )

# %%
features_df.head(100)
# Out:
#              receive_ts  dist_bid_price_0  dist_bid_price_1  dist_bid_price_2  \
# 0   2024-12-18 08:58:06          0.000000        -13.490075        -14.453652
# 1   2024-12-18 08:58:07          0.000000        -47.215263       -182.116015
# 2   2024-12-18 08:58:08          0.000000         -5.781461        -14.453652
# 3   2024-12-18 08:58:09          0.000000         -5.781589         -6.745187
# 4   2024-12-18 08:58:10          0.000000         -5.781589         -6.745187
# ..                  ...               ...               ...               ...
# 95  2024-12-18 08:59:41         -0.481648         -9.151303        -12.041189
# 96  2024-12-18 08:59:42         -0.481648        -13.004484        -15.894369
# 97  2024-12-18 08:59:43         -0.481648         -2.408238         -3.371533
# 98  2024-12-18 08:59:44         -0.481648         -3.371533         -4.334828
# 99  2024-12-18 08:59:45         -0.481648        -30.343795        -63.095828
#
#     dist_bid_price_3  dist_bid_price_4  dist_bid_price_5  dist_bid_price_6  \
# 0         -47.215263        -56.851031        -63.596069        -75.158990
# 1        -211.986895       -235.112738       -265.947196       -393.139333
# 2         -22.162266        -27.943727        -36.615918        -38.543072
# 3          -9.635982        -14.453972        -16.381169        -23.126356
# 4          -9.635982        -14.453972        -15.417570        -16.381169
# ..               ...               ...               ...               ...
# 95        -13.004484        -22.637435        -30.343795        -37.086861
# 96        -21.674139        -22.637435        -37.086861        -47.683107
# 97         -4.334828        -13.004484        -13.967779        -15.894369
# 98         -6.261418        -13.004484        -21.674139        -22.637435
# 99       -115.113763       -149.792386       -190.250779       -224.929403
#
#     dist_bid_price_7  dist_bid_price_8  ...  national_imbalance_0  \
# 0         -88.649065       -103.102717  ...              0.352411
# 1        -491.424167       -501.059934  ...              0.406870
# 2         -48.178840        -49.142417  ...              0.790178
# 3         -26.017150        -28.907945  ...              0.999740
# 4         -23.126356        -28.907945  ...              0.855698
# ..               ...               ...  ...                   ...
# 95        -47.683107        -60.205943  ...              0.995262
# 96        -61.169238        -94.884566  ...              0.908694
# 97        -22.637435        -26.490615  ...              0.547106
# 98        -37.086861        -99.701041  ...              0.546147
# 99       -312.589255       -327.038682  ...              0.557533
#
#     national_imbalance_1  national_imbalance_2  national_imbalance_3  \
# 0               0.352401              0.345027              0.344846
# 1               0.449466              0.387539              0.256702
# 2               0.808916              0.817273              0.822471
# 3               0.999399              0.999372              0.999297
# 4               0.855675              0.881935              0.881937
# ..                   ...                   ...                   ...
# 95              0.995903              0.995903              0.995999
# 96              0.912926              0.884507              0.884487
# 97              0.560055              0.560038              0.544907
# 98              0.546777              0.546754              0.532678
# 99              0.561050              0.530588              0.530588
#
#     national_imbalance_4  national_imbalance_5  national_imbalance_6  \
# 0               0.344857              0.360368              0.372773
# 1               0.086654              0.086542              0.085247
# 2               0.790264              0.790008              0.789316
# 3               0.999279              0.996896              0.996799
# 4               0.881891              0.882241              0.885785
# ..                   ...                   ...                   ...
# 95              0.995875              0.995814              0.972129
# 96              0.884380              0.884565              0.877655
# 97              0.547397              0.519215              0.520228
# 98              0.532708              0.532957              0.533025
# 99              0.528053              0.479675              0.477391
#
#     national_imbalance_7  national_imbalance_8  national_imbalance_9
# 0               0.346659              0.346659              0.271395
# 1               0.089785              0.056223              0.056223
# 2               0.779567              0.779567              0.781069
# 3               0.998115              0.998173              0.998151
# 4               0.891105              0.891186              0.891172
# ..                   ...                   ...                   ...
# 95              0.966149              0.966149              0.958797
# 96              0.877808              0.876909              0.868520
# 97              0.512894              0.512691              0.516958
# 98              0.494142              0.480040              0.480030
# 99              0.477391              0.496552              0.496497
#
# [100 rows x 51 columns]

# %%
bid_price = lobs_df['bid_price_0']
ask_price = lobs_df['ask_price_0']
bid_vol = lobs_df['bid_vol_0']
ask_vol = lobs_df['ask_vol_0']

prev_bid_price = lobs_df['bid_price_0'].shift(1)
prev_ask_price = lobs_df['ask_price_0'].shift(1)
prev_bid_vol = lobs_df['bid_vol_0'].shift(1)
prev_ask_vol = lobs_df['ask_vol_0'].shift(1)

features_df['order_flow_imbalance'] = (
        (bid_price >= prev_bid_price) * bid_vol -
        (bid_price <= prev_bid_price) * prev_bid_vol -
        (ask_price <= prev_ask_price) * ask_vol +
        (ask_price >= prev_ask_price) * prev_ask_vol
)
features_df['order_flow_imbalance'].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_3765999/2303828957.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   features_df['order_flow_imbalance'].fillna(0, inplace=True)

# %%
features_df['spread'] = (lobs_df['ask_price_0'] - lobs_df['bid_price_0']) / lobs_df['mid_price'] * 1e06

# %%
features_df.head()
# Out:
#             receive_ts  dist_bid_price_0  dist_bid_price_1  dist_bid_price_2  \
# 0  2024-12-18 08:58:06               0.0        -13.490075        -14.453652
# 1  2024-12-18 08:58:07               0.0        -47.215263       -182.116015
# 2  2024-12-18 08:58:08               0.0         -5.781461        -14.453652
# 3  2024-12-18 08:58:09               0.0         -5.781589         -6.745187
# 4  2024-12-18 08:58:10               0.0         -5.781589         -6.745187
#
#    dist_bid_price_3  dist_bid_price_4  dist_bid_price_5  dist_bid_price_6  \
# 0        -47.215263        -56.851031        -63.596069        -75.158990
# 1       -211.986895       -235.112738       -265.947196       -393.139333
# 2        -22.162266        -27.943727        -36.615918        -38.543072
# 3         -9.635982        -14.453972        -16.381169        -23.126356
# 4         -9.635982        -14.453972        -15.417570        -16.381169
#
#    dist_bid_price_7  dist_bid_price_8  ...  national_imbalance_2  \
# 0        -88.649065       -103.102717  ...              0.345027
# 1       -491.424167       -501.059934  ...              0.387539
# 2        -48.178840        -49.142417  ...              0.817273
# 3        -26.017150        -28.907945  ...              0.999372
# 4        -23.126356        -28.907945  ...              0.881935
#
#    national_imbalance_3  national_imbalance_4  national_imbalance_5  \
# 0              0.344846              0.344857              0.360368
# 1              0.256702              0.086654              0.086542
# 2              0.822471              0.790264              0.790008
# 3              0.999297              0.999279              0.996896
# 4              0.881937              0.881891              0.882241
#
#    national_imbalance_6  national_imbalance_7  national_imbalance_8  \
# 0              0.372773              0.346659              0.346659
# 1              0.085247              0.089785              0.056223
# 2              0.789316              0.779567              0.779567
# 3              0.996799              0.998115              0.998173
# 4              0.885785              0.891105              0.891186
#
#    national_imbalance_9  order_flow_imbalance  spread
# 0              0.271395               0.00000     0.0
# 1              0.056223              -0.21580     0.0
# 2              0.781069              -1.81601     0.0
# 3              0.998151              -7.83294     0.0
# 4              0.891172               0.77462     0.0
#
# [5 rows x 53 columns]

# %%
for w in windows.values():
    features_df[f'CRSI_{w}'] = (
            (lobs_df[f'gain_{w}'] - lobs_df[f'loss_{w}'].abs()) /
            (lobs_df[f'gain_{w}'] + lobs_df[f'loss_{w}'].abs())
    ).fillna(0)

# %%
features_df.tail()
# Out:
#                 receive_ts  dist_bid_price_0  dist_bid_price_1  \
# 26636  2024-12-18 16:22:11               0.0         -2.898148
# 26637  2024-12-18 16:22:12               0.0         -1.931906
# 26638  2024-12-18 16:22:13               0.0         -0.965863
# 26639  2024-12-18 16:22:14               0.0         -0.965550
# 26640  2024-12-18 16:22:15               0.0         -2.896650
#
#        dist_bid_price_2  dist_bid_price_3  dist_bid_price_4  dist_bid_price_5  \
# 26636         -3.864197         -4.830246         -6.762344        -15.456787
# 26637         -2.897859         -3.863812         -4.829765         -6.761671
# 26638         -1.931725         -3.863450         -4.829313         -5.795175
# 26639         -2.896650         -6.758851         -8.689951         -9.655501
# 26640         -6.758851         -8.689951         -9.655501        -12.552152
#
#        dist_bid_price_6  dist_bid_price_7  dist_bid_price_8  ...  \
# 26636        -18.354934        -19.320983        -23.185180  ...
# 26637        -10.625484        -11.591437        -12.557390  ...
# 26638         -7.726900         -8.692763        -12.556213  ...
# 26639        -10.621052        -11.586602        -13.517702  ...
# 26640        -13.517702        -19.311003        -21.242103  ...
#
#        national_imbalance_5  national_imbalance_6  national_imbalance_7  \
# 26636             -0.521786             -0.535293             -0.551307
# 26637             -0.675715             -0.675656             -0.667856
# 26638             -0.927996             -0.927908             -0.923020
# 26639              0.833563              0.833563              0.833563
# 26640              0.407531              0.407479              0.414672
#
#        national_imbalance_8  national_imbalance_9  order_flow_imbalance  \
# 26636             -0.553797             -0.553844              -6.38671
# 26637             -0.663819             -0.663608               4.06696
# 26638             -0.922791             -0.899463               3.63341
# 26639              0.711516              0.712369               0.26215
# 26640              0.414635              0.429425              -0.04540
#
#        spread   CRSI_1m   CRSI_5m  CRSI_15m
# 26636     0.0 -0.077620 -0.085931 -0.164109
# 26637     0.0 -0.041241 -0.072284 -0.162609
# 26638     0.0 -0.024924 -0.067865 -0.161806
# 26639     0.0  0.027693 -0.052880 -0.155822
# 26640     0.0  0.027693 -0.052880 -0.155254
#
# [5 rows x 56 columns]

# %%
features_df['ESS'] = features_df.iloc[:, 1:].values.tolist()

# %%
import pickle
features_dict = features_df.set_index('receive_ts')['ESS'].to_dict()
with open(lobs_pkl, 'wb') as f:
    pickle.dump(features_dict, f)
